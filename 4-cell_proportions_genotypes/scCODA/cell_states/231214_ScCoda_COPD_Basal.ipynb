# %% [markdown]
# # Compositional analysis of the COPD-IAV scRNA dataset using scCoda (pertpy):
# - Developed by: Christian Eger
# - Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg
# - Created on: 231214
# - Last modified: 240108<br>
# 6 Patients with and 6 without chronic obstructive pulmonary disease (COPD).
# Epithelial cells extracted with a lung wash and exposed to IAV (Control and IAV n=3 for both COPD and healthy patients)
# --> scRNA-seq and cell types annotated

# %% [markdown]
# ### Preparation of the mamba environment

# %% [markdown]
# Created mamba environment in /Users/egerc/miniforge3/envs/pertpy-env
# mamba create -n pertpy-env python=3.10
# mamba activate pertpy-env<br>
# Manual git installation of pertpy necessary due to Apple silicon
# git clone https://github.com/theislab/pertpy.git
# cd pertpy
# pip install .

# %%
import warnings

import pandas as pd

warnings.filterwarnings("ignore")
warnings.simplefilter("ignore")

import scanpy as sc
import numpy as np
#import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import altair as alt
import pertpy as pt
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
sc.logging.print_versions()
# Out:
# -----
# anndata     0.10.4
# scanpy      1.9.6
# -----
# PIL                         10.2.0
# absl                        NA
# adjustText                  0.8
# aiohttp                     3.9.1
# aiosignal                   1.3.1
# altair                      5.2.0
# annotated_types             0.6.0
# anyio                       NA
# appnope                     0.1.3
# arrow                       1.3.0
# arviz                       0.17.0
# asttokens                   NA
# async_timeout               4.0.3
# attr                        23.2.0
# attrs                       23.2.0
# backoff                     2.2.1
# bs4                         4.12.2
# certifi                     2023.11.17
# cffi                        1.16.0
# chardet                     5.2.0
# charset_normalizer          3.3.2
# chex                        0.1.7
# click                       8.1.7
# comm                        0.2.1
# contextlib2                 NA
# croniter                    NA
# custom_inherit              2.4.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.0
# decorator                   5.1.1
# decoupler                   1.5.0
# deepdiff                    6.7.1
# docrep                      0.3.2
# etils                       1.6.0
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastapi                     0.108.0
# flax                        0.7.5
# frozenlist                  1.4.1
# fsspec                      2023.12.2
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.10.8
# importlib_resources         NA
# ipykernel                   6.28.0
# jax                         0.4.23
# jaxlib                      0.4.23
# jaxopt                      NA
# jedi                        0.19.1
# jinja2                      3.1.2
# joblib                      1.3.2
# jsonschema                  4.20.0
# jsonschema_specifications   NA
# kiwisolver                  1.4.5
# leidenalg                   0.10.1
# lightning                   2.0.9.post0
# lightning_cloud             0.5.57
# lightning_fabric            2.1.3
# lightning_utilities         0.10.0
# llvmlite                    0.41.1
# markupsafe                  2.1.3
# matplotlib                  3.8.2
# ml_collections              NA
# ml_dtypes                   0.3.2
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.0.7
# mudata                      0.2.3
# multidict                   6.0.4
# multipart                   0.0.6
# multipledispatch            0.6.0
# natsort                     8.4.0
# numba                       0.58.1
# numpy                       1.26.3
# numpyro                     0.13.2
# opt_einsum                  v3.3.0
# optax                       0.1.7
# ordered_set                 4.1.0
# ott                         0.4.5
# packaging                   23.2
# pandas                      2.1.4
# parso                       0.8.3
# patsy                       0.5.6
# pertpy                      0.7.0
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                4.1.0
# ply                         3.11
# png                         0.20220715.0
# prompt_toolkit              3.0.42
# psutil                      5.9.7
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pycparser                   2.21
# pydantic                    2.1.1
# pydantic_core               2.4.0
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyomo                       6.7.0
# pyparsing                   3.1.1
# pyro                        1.8.6
# pytorch_lightning           2.1.3
# pytz                        2023.3.post1
# referencing                 NA
# reportlab                   4.0.8
# requests                    2.31.0
# rich                        NA
# rpds                        NA
# rpy2                        3.5.11
# scipy                       1.11.4
# scvi                        1.0.4
# seaborn                     0.13.1
# session_info                1.0.0
# six                         1.16.0
# sklearn                     1.3.2
# skmisc                      0.3.1
# sniffio                     1.3.0
# soupsieve                   2.5
# sparse                      0.14.0
# sparsecca                   0.3.1
# stack_data                  0.6.2
# starlette                   0.32.0.post1
# statsmodels                 0.14.1
# sympy                       1.12
# texttable                   1.7.0
# threadpoolctl               3.2.0
# toolz                       0.12.0
# torch                       2.1.2
# torchgen                    NA
# torchmetrics                1.2.1
# tornado                     6.3.3
# toyplot                     1.0.3
# toytree                     2.0.1
# tqdm                        4.66.1
# traitlets                   5.14.1
# tree                        0.1.8
# typing_extensions           NA
# tzlocal                     NA
# urllib3                     2.0.7
# uvicorn                     0.25.0
# wcwidth                     0.2.12
# websocket                   1.7.0
# websockets                  12.0
# xarray                      2023.12.0
# xarray_einstats             0.6.0
# yaml                        6.0.1
# yarl                        1.9.4
# zmq                         25.1.2
# zoneinfo                    NA
# -----
# IPython             8.19.0
# jupyter_client      8.6.0
# jupyter_core        5.7.0
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]
# macOS-14.2.1-arm64-arm-64bit
# -----
# Session information updated at 2024-01-08 10:43

# %% [markdown]
# ### Preparation of AnnData object
#
# 1. Creation of adata from h5ad file
# 2. Subsetting the adata dataframe to the cell_compartment of choice

# %%
adata = sc.read_h5ad("Marburg_cell_states_locked_scANVI_ctl230901.raw.h5ad")
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 97573 × 27208
#     obs: 'sex', 'age', 'ethnicity', 'PaCO2', 'donor', 'infection', 'disease', 'SMK', 'illumina_stimunr', 'bd_rhapsody', 'n_genes', 'doublet_scores', 'predicted_doublets', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt2', 'n_counts', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'condition', 'sample_group', 'IAV_score', 'group', 'Viral_score', 'cell_type', 'cell_states', 'leiden', 'cell_compartment', 'seed_labels', '_scvi_batch', '_scvi_labels', 'C_scANVI'
#     var: 'mt', 'ribo'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'

# %%
adata.obs.cell_compartment.unique().tolist()
#prints a list of possible cell_compartments to subset adata to
# Out:
# ['Ciliated',
#  'Club',
#  'Deuterosomal',
#  'Unknown',
#  'Goblet',
#  'Basal',
#  'Ionocyte',
#  'Secretory',
#  'SupraB',
#  'Epi']

# %%
adata_cell_compartment = adata[adata.obs['cell_compartment'].isin(['Basal'])]
adata_cell_compartment
# Out:
# View of AnnData object with n_obs × n_vars = 38193 × 27208
#     obs: 'sex', 'age', 'ethnicity', 'PaCO2', 'donor', 'infection', 'disease', 'SMK', 'illumina_stimunr', 'bd_rhapsody', 'n_genes', 'doublet_scores', 'predicted_doublets', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt2', 'n_counts', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'condition', 'sample_group', 'IAV_score', 'group', 'Viral_score', 'cell_type', 'cell_states', 'leiden', 'cell_compartment', 'seed_labels', '_scvi_batch', '_scvi_labels', 'C_scANVI'
#     var: 'mt', 'ribo'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'

# %%
sccoda_model = pt.tl.Sccoda()
sccoda_data = sccoda_model.load(
    adata_cell_compartment,
    type="cell_level",
    generate_sample_level=True,
    cell_type_identifier="cell_states",
    sample_identifier="batch",
    covariate_obs=["infection", "disease", "group"],
)
# https://pertpy.readthedocs.io/en/latest/usage/tools/pertpy.tools.Sccoda.html#pertpy.tools.Sccoda.load
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 38217 × 27219
#   2 modalities
#     rna:	38193 x 27208
#       obs:	'sex', 'age', 'ethnicity', 'PaCO2', 'donor', 'infection', 'disease', 'SMK', 'illumina_stimunr', 'bd_rhapsody', 'n_genes', 'doublet_scores', 'predicted_doublets', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt2', 'n_counts', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'condition', 'sample_group', 'IAV_score', 'group', 'Viral_score', 'cell_type', 'cell_states', 'leiden', 'cell_compartment', 'seed_labels', '_scvi_batch', '_scvi_labels', 'C_scANVI', 'scCODA_sample_id'
#       var:	'mt', 'ribo'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#     coda:	24 x 11
#       obs:	'infection', 'disease', 'group', 'batch'
#       var:	'n_cells'

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="group",
    y_scale="count",
    plot_facets=False,
    figsize=(12, 6),
    dpi=100,
    cmap="colorblind",
    add_dots=False,
    show_legend="True",
    level_order=[],
    args_swarmplot={"palette": ["blue"]},
    args_boxplot={"order": None,
                  "orient": "v",
                  "color": "green",
                  "saturation": 1,
                  "dodge": True,
                  "width": 1,
                  "linewidth": 1.6}
)
#Parameters: https://pertpy.readthedocs.io/en/latest/usage/tools/pertpy.tools.Sccoda.html#pertpy.tools.Sccoda.plot_boxplots

plt.show()

# %%
pt.pl.coda.stacked_barplot(
    sccoda_data, 
    modality_key="coda",
    feature_name="group", 
    figsize=(4, 2)
)
plt.show()

# %% [markdown]
# ### Data modelling using ScCoda

# %% [markdown]
# Function sccoda.run_nuts() broken at the moment
# https://github.com/theislab/pertpy/issues/454
# Downgrading Jax didn't solve the issue for me.

# %% [markdown]
# --> solution: completely new environment, install jax=0.4.20 prior to installing pertpy

# %%
sccoda_data = sccoda_model.prepare(
    sccoda_data,
    modality_key="coda",
    formula="infection",
    reference_cell_type="automatic",
)
sccoda_model.run_nuts(sccoda_data, modality_key="coda", rng_key=1234)
# Out:
# Automatic reference selection! Reference cell type set to IGFBP6+Basal
# Zero counts encountered in data! Added a pseudocount of 0.5.
# sample: 100%|██████████| 11000/11000 [01:30<00:00, 122.03it/s, 255 steps of size 1.44e-02. acc. prob=0.92]

# %%
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 38217 × 27219
#   2 modalities
#     rna:	38193 x 27208
#       obs:	'sex', 'age', 'ethnicity', 'PaCO2', 'donor', 'infection', 'disease', 'SMK', 'illumina_stimunr', 'bd_rhapsody', 'n_genes', 'doublet_scores', 'predicted_doublets', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt2', 'n_counts', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'condition', 'sample_group', 'IAV_score', 'group', 'Viral_score', 'cell_type', 'cell_states', 'leiden', 'cell_compartment', 'seed_labels', '_scvi_batch', '_scvi_labels', 'C_scANVI', 'scCODA_sample_id'
#       var:	'mt', 'ribo'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#     coda:	24 x 11
#       obs:	'infection', 'disease', 'group', 'batch'
#       var:	'n_cells'
#       uns:	'scCODA_params'
#       obsm:	'covariate_matrix', 'sample_counts'
#       varm:	'intercept_df', 'effect_df_infection[T.IAV]'

# %%
sccoda_model.set_fdr(sccoda_data, 0.2)

# %%
sccoda_model.credible_effects(sccoda_data, modality_key="coda")
# Out:
# Covariate         Cell Type
# infection[T.IAV]  IGFBP6+Basal      False
#                   SERPINE1+Basal     True
#                   SERPINE2+Basal    False
#                   CCDC3+Basal1      False
#                   FB-like_Basal      True
#                   IGFBP+Basal       False
#                   MKI67+pBasal      False
#                   NOTCH+Basal2      False
#                   S100A2+Basal      False
#                   TNC+Basal         False
#                   ifn_Basal          True
# Name: Final Parameter, dtype: bool

# %%
sccoda_data["coda"].varm["effect_df_infection[T.IAV]"]
# Out:
#                 Final Parameter  HDI 3%  HDI 97%     SD  \
# Cell Type
# IGFBP6+Basal           0.000000   0.000    0.000  0.000
# SERPINE1+Basal         1.378786   0.619    2.130  0.411
# SERPINE2+Basal         0.000000  -1.178    0.085  0.384
# CCDC3+Basal1           0.000000  -0.668    0.237  0.144
# FB-like_Basal         -0.668177  -1.136   -0.108  0.305
# IGFBP+Basal            0.000000  -0.405    0.383  0.099
# MKI67+pBasal           0.000000  -0.334    0.463  0.105
# NOTCH+Basal2           0.000000  -0.786    0.276  0.180
# S100A2+Basal           0.000000  -0.804    0.219  0.196
# TNC+Basal              0.000000  -0.491    0.574  0.148
# ifn_Basal              2.321851   1.597    2.967  0.359
#
#                 Inclusion probability  Expected Sample  log2-fold change
# Cell Type
# IGFBP6+Basal                   0.0000        65.137028         -0.063047
# SERPINE1+Basal                 0.9916        68.805214          1.926121
# SERPINE2+Basal                 0.5524        58.879511         -0.063047
# CCDC3+Basal1                   0.2668       203.668397         -0.063047
# FB-like_Basal                  0.9109       176.322777         -1.027022
# IGFBP+Basal                    0.2282       258.137701         -0.063047
# MKI67+pBasal                   0.2338       264.407948         -0.063047
# NOTCH+Basal2                   0.3041        99.136052         -0.063047
# S100A2+Basal                   0.3337       126.152711         -0.063047
# TNC+Basal                      0.2710        66.852799         -0.063047
# ifn_Basal                      1.0000       204.249863          3.286676

# %%
order = sccoda_data["coda"].varm["effect_df_infection[T.IAV]"].groupby("Cell Type")["log2-fold change"].mean().fillna(0).sort_values()[::-1].index.tolist()
plt.figure(figsize=(20,8))
sns.barplot(data=sccoda_data["coda"].varm["effect_df_infection[T.IAV]"], x="Cell Type", y="log2-fold change", hue="Cell Type", order=order)
# Out:
# <Axes: xlabel='Cell Type', ylabel='log2-fold change'>

# %% [markdown]
# ### Plotting of cell_states change of given cell_compartment in groups healthy_iav, copd_ctrl and copd_iav with healthy_ctrl as a reference

# %%
pt.pl.coda.effects_barplot(sccoda_data, "coda", "group")
plt.show()
