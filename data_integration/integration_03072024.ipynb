# %% [markdown]
# # Notebook to run data integration of 'GSE143437' dataset
#
# - **Developed by**: Srivalli Kolla
# - **Created date** : 03 July, 2024
# - **Modification date** : 03 July, 2024
# - **Würzburg Institute for Systems Immunology & Julius-Maximilian-Universität Würzburg**

# %% [markdown]
# # Import packages

# %%
import anndata as ad
import scanpy as sc

# %%
path = '../data/'

# %% [markdown]
# # Cardiomyocytes

# %% [markdown]
# ## Data loading

# %%
cmc = ad.read_h5ad(path + 'heart_mm_nuclei-23-0092_CMC_states_ctl240131.raw.h5ad')
GSE143437 = ad.read_h5ad(path + 'GSE143437_QC_03_07_2024_raw.h5ad')


print("Columns in cmc.obs:", cmc.obs.columns)
print("Columns in GSE143437.obs:", GSE143437.obs.columns)
print("Columns in cmc.var:", cmc.var.columns)
print("Columns in GSE143437.var:", GSE143437.var.columns)
# Out:
# Columns in cmc.obs: Index(['cell_source', 'cell_type', 'donor', 'n_counts', 'n_genes',
#        'percent_mito', 'percent_ribo', 'region', 'sample', 'scrublet_score',
#        'cell_states', 'seed_labels', 'genotype', 'batch', 'doublet_scores',
#        'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt',
#        'total_counts_ribo', 'pct_counts_ribo', 'percent_mt2', 'percent_chrY',
#        'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels',
#        'C_scANVI'],
#       dtype='object')
# Columns in GSE143437.obs: Index(['sample_id', 'sample_identifier', 'nUMI', 'nGene', 'percent_mito',
#        'injury', 'cell_annotation', 'doublet_scores', 'predicted_doublets',
#        'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt',
#        'total_counts_ribo', 'pct_counts_ribo', 'percent_chrY', 'XIST-counts',
#        'XIST-percentage', 'gender_check_cov', 'S_score', 'G2M_score', 'phase'],
#       dtype='object')
# Columns in cmc.var: Index(['gene_ids', 'feature_types', 'genome', 'mt', 'ribo',
#        'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts',
#        'total_counts'],
#       dtype='object')
# Columns in GSE143437.var: Index(['mt', 'ribo', 'n_cells_by_counts', 'mean_counts',
#        'pct_dropout_by_counts', 'total_counts'],
#       dtype='object')

# %% [markdown]
# ## Column renaming

# %% [markdown]
# ##### Steps
#
# 1. Create and delete columns required
# 2. Mapping for columns that have the same information but different names
# 3. Rename columns in cmc to match those in GSE143437
# 4. Handle duplicate columns by making them unique
# 5. Find common columns and convert to list
# 6. Filter and rename columns in cmc and GSE143437 to match AnnData expectations
# 7. Concatenate the two datasets with inner join

# %%
cmc.obs['gender_check_cov'] = 'Male' 

del cmc.obs['cell_type']

obs_rename_mapping = {
    'donor' : 'sample_identifier' ,
    'sample': 'sample_id',
    'n_genes': 'nGene',
    'percent_mito': 'pct_counts_mt',
    'percent_ribo': 'pct_counts_ribo',
    'pct_counts_mt' : 'pct_counts_mt', 
    'C_scANVI' : 'cell_annotation'
}


cmc.obs.rename(columns=obs_rename_mapping, inplace=True)


def make_unique(column_names):
    seen = set()
    for idx, col in enumerate(column_names):
        while col in seen:
            col += '_dup'
        seen.add(col)
        column_names[idx] = col
    return column_names

cmc.obs.columns = make_unique(list(cmc.obs.columns))
GSE143437.obs.columns = make_unique(list(GSE143437.obs.columns))

cmc.var.columns = make_unique(list(cmc.var.columns))
GSE143437.var.columns = make_unique(list(GSE143437.var.columns))

common_obs_columns = list(set(cmc.var.columns).intersection(set(GSE143437.var.columns)))
common_var_columns = list(set(cmc.var.columns).intersection(set(GSE143437.var.columns)))

cmc = cmc[:, cmc.var_names.isin(common_var_columns)].copy()
GSE143437 = GSE143437[:, GSE143437.var_names.isin(common_var_columns)].copy()

# %% [markdown]
# ## Integration

# %%
integrated_cmc = ad.concat([cmc, GSE143437], join='inner', index_unique=None)
integrated_cmc.obs
# Out:
# /Users/srivalli/conda/envs/anndata/lib/python3.12/site-packages/anndata/_core/merge.py:1356: UserWarning: Only some AnnData objects have `.raw` attribute, not concatenating `.raw` attributes.
#   warn(
#                         sample_identifier   nGene  pct_counts_mt  \
# ACACTGATCATTATCC-1-A9_2              A9_2  3851.0            NaN
# TCTTCCTGTCATAACC-1-A9_2              A9_2  3577.0            NaN
# ATCTCTAGTTTCAGAC-1-A9_2              A9_2  3632.0            NaN
# TGAATGCAGCTCCATA-1-A9_2              A9_2  3691.0            NaN
# GCAGCTGCACAAGTGG-1-A9_2              A9_2  3778.0            NaN
# ...                                   ...     ...            ...
# D7_D_TTTGTCAAGGTGTTAA                D7_D  1173.0       3.552554
# D7_D_TTTGTCACAGTCAGCC                D7_D  3268.0       1.923886
# D7_D_TTTGTCACATCGATGT                D7_D  2432.0       0.779578
# D7_D_TTTGTCAGTCCGTTAA                D7_D  1407.0       1.275917
# D7_D_TTTGTCAGTTTGTGTG                D7_D  3210.0       0.703876
#
#                          pct_counts_ribo    sample_id  doublet_scores  \
# ACACTGATCATTATCC-1-A9_2              NaN         A9_2        0.049904
# TCTTCCTGTCATAACC-1-A9_2              NaN         A9_2        0.048159
# ATCTCTAGTTTCAGAC-1-A9_2              NaN         A9_2        0.043243
# TGAATGCAGCTCCATA-1-A9_2              NaN         A9_2        0.057495
# GCAGCTGCACAAGTGG-1-A9_2              NaN         A9_2        0.061702
# ...                                  ...          ...             ...
# D7_D_TTTGTCAAGGTGTTAA          12.536700  SRR10870305        0.063719
# D7_D_TTTGTCACAGTCAGCC          12.352817  SRR10870305        0.053763
# D7_D_TTTGTCACATCGATGT           9.859370  SRR10870305        0.034757
# D7_D_TTTGTCAGTCCGTTAA           7.934609  SRR10870305        0.006983
# D7_D_TTTGTCAGTTTGTGTG          11.668484  SRR10870305        0.027473
#
#                          n_genes_by_counts  total_counts  total_counts_mt  \
# ACACTGATCATTATCC-1-A9_2             3851.0       14981.0              4.0
# TCTTCCTGTCATAACC-1-A9_2             3577.0       14906.0              4.0
# ATCTCTAGTTTCAGAC-1-A9_2             3632.0       14969.0              1.0
# TGAATGCAGCTCCATA-1-A9_2             3691.0       14086.0             23.0
# GCAGCTGCACAAGTGG-1-A9_2             3778.0       14125.0             15.0
# ...                                    ...           ...              ...
# D7_D_TTTGTCAAGGTGTTAA               1166.0        3406.0            121.0
# D7_D_TTTGTCACAGTCAGCC               3370.0        9512.0            183.0
# D7_D_TTTGTCACATCGATGT               2456.0        6542.0             51.0
# D7_D_TTTGTCAGTCCGTTAA               1420.0        2508.0             32.0
# D7_D_TTTGTCAGTTTGTGTG               3287.0       10087.0             71.0
#
#                          total_counts_ribo  percent_chrY  XIST-counts  \
# ACACTGATCATTATCC-1-A9_2                6.0      0.046726          0.0
# TCTTCCTGTCATAACC-1-A9_2               10.0      0.080504          0.0
# ATCTCTAGTTTCAGAC-1-A9_2                9.0      0.053444          0.0
# TGAATGCAGCTCCATA-1-A9_2               18.0      0.078092          1.0
# GCAGCTGCACAAGTGG-1-A9_2               11.0      0.028319          0.0
# ...                                    ...           ...          ...
# D7_D_TTTGTCAAGGTGTTAA                427.0      0.000000          2.0
# D7_D_TTTGTCACAGTCAGCC               1175.0      0.021026         37.0
# D7_D_TTTGTCACATCGATGT                645.0      0.015286          4.0
# D7_D_TTTGTCAGTCCGTTAA                199.0      0.000000          0.0
# D7_D_TTTGTCAGTTTGTGTG               1177.0      0.000000         12.0
#
#                           S_score  G2M_score                cell_annotation  \
# ACACTGATCATTATCC-1-A9_2 -0.218301  -0.450239                           vCM2
# TCTTCCTGTCATAACC-1-A9_2  0.084806  -0.395886                           vCM2
# ATCTCTAGTTTCAGAC-1-A9_2 -0.352962  -0.206640                           vCM2
# TGAATGCAGCTCCATA-1-A9_2 -0.159373  -0.494394                           vCM2
# GCAGCTGCACAAGTGG-1-A9_2  0.351369  -0.141495                           vCM2
# ...                           ...        ...                            ...
# D7_D_TTTGTCAAGGTGTTAA   -0.210280  -0.512819  Anti-inflammatory macrophages
# D7_D_TTTGTCACAGTCAGCC   -0.064807   3.910752          MuSCs and progenitors
# D7_D_TTTGTCACATCGATGT   -0.206855  -0.657905                           FAPs
# D7_D_TTTGTCAGTCCGTTAA   -0.480220  -0.241352                    Endothelial
# D7_D_TTTGTCAGTTTGTGTG   -0.534799  -1.216019                           FAPs
#
#                         gender_check_cov
# ACACTGATCATTATCC-1-A9_2             Male
# TCTTCCTGTCATAACC-1-A9_2             Male
# ATCTCTAGTTTCAGAC-1-A9_2             Male
# TGAATGCAGCTCCATA-1-A9_2             Male
# GCAGCTGCACAAGTGG-1-A9_2             Male
# ...                                  ...
# D7_D_TTTGTCAAGGTGTTAA             Female
# D7_D_TTTGTCACAGTCAGCC             Female
# D7_D_TTTGTCACATCGATGT             Female
# D7_D_TTTGTCAGTCCGTTAA               None
# D7_D_TTTGTCAGTTTGTGTG             Female
#
# [40771 rows x 16 columns]

# %%
cmc.write(path + 'cmc_integrated_gse143437.h5ad')

# %% [markdown]
# # Fibroblasts

# %% [markdown]
# ## Data loading

# %%
fb = ad.read_h5ad(path + 'heart_mm_nuclei-23-0092_FB_states_ctl240131.raw.h5ad')
GSE143437 = ad.read_h5ad(path + 'GSE143437_QC_03_07_2024_raw.h5ad')

print("Columns in fb.obs:", fb.obs.columns)
print("Columns in GSE143437.obs:", GSE143437.obs.columns)
# Out:
# Columns in fb.obs: Index(['cell_source', 'cell_type', 'donor', 'n_counts', 'n_genes',
#        'percent_mito', 'percent_ribo', 'region', 'sample', 'scrublet_score',
#        'cell_states', 'seed_labels', 'genotype', 'batch', 'doublet_scores',
#        'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt',
#        'total_counts_ribo', 'pct_counts_ribo', 'percent_mt2', 'percent_chrY',
#        'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels',
#        'C_scANVI'],
#       dtype='object')
# Columns in GSE143437.obs: Index(['sample_id', 'sample_identifier', 'nUMI', 'nGene', 'percent_mito',
#        'injury', 'cell_annotation', 'doublet_scores', 'predicted_doublets',
#        'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt',
#        'total_counts_ribo', 'pct_counts_ribo', 'percent_chrY', 'XIST-counts',
#        'XIST-percentage', 'gender_check_cov', 'S_score', 'G2M_score', 'phase'],
#       dtype='object')

# %% [markdown]
# ## Column renaming

# %% [markdown]
# ##### Steps
#
# 1. Mapping for columns that have the same information but different names
# 2. Rename columns in cmc to match those in GSE143437
# 3. Handle duplicate columns by making them unique
# 4. Find common columns and convert to list
# 5. Filter and rename columns in cmc and GSE143437 to match AnnData expectations
# 6. Concatenate the two datasets with inner join

# %%
fb.obs['gender_check_cov'] = 'Male' 

del fb.obs['cell_type']

obs_rename_mapping = {
    'donor' : 'sample_identifier' ,
    'sample': 'sample_id',
    'n_genes': 'nGene',
    'percent_mito': 'pct_counts_mt',
    'percent_ribo': 'pct_counts_ribo',
    'pct_counts_mt' : 'pct_counts_mt', 
    'C_scANVI' : 'cell_annotation'
}


fb.obs.rename(columns=obs_rename_mapping, inplace=True)


def make_unique(column_names):
    seen = set()
    for idx, col in enumerate(column_names):
        while col in seen:
            col += '_dup'
        seen.add(col)
        column_names[idx] = col
    return column_names

fb.obs.columns = make_unique(list(fb.obs.columns))
GSE143437.obs.columns = make_unique(list(GSE143437.obs.columns))

fb.var.columns = make_unique(list(fb.var.columns))
GSE143437.var.columns = make_unique(list(GSE143437.var.columns))

common_obs_columns = list(set(fb.var.columns).intersection(set(GSE143437.var.columns)))
common_var_columns = list(set(fb.var.columns).intersection(set(GSE143437.var.columns)))

fb = fb[:, fb.var_names.isin(common_var_columns)].copy()
GSE143437 = GSE143437[:, GSE143437.var_names.isin(common_var_columns)].copy()

# %% [markdown]
# ## Integration

# %%
integrated_fb = ad.concat([fb, GSE143437], join='inner', index_unique=None)
integrated_fb.obs
# Out:
# /Users/srivalli/conda/envs/anndata/lib/python3.12/site-packages/anndata/_core/merge.py:1356: UserWarning: Only some AnnData objects have `.raw` attribute, not concatenating `.raw` attributes.
#   warn(
#                         sample_identifier   nGene  pct_counts_mt  \
# TCGCAGGAGGCTTCCG-1-A9_2              A9_2  4100.0            NaN
# CCGTTCACAAATTGCC-1-A9_2              A9_2  3727.0            NaN
# CCAAGCGGTTTCGTAG-1-A9_2              A9_2  3080.0            NaN
# AACGGGACACTCAAGT-1-A9_2              A9_2  3271.0            NaN
# GGAATGGAGACAACAT-1-A9_2              A9_2  2987.0            NaN
# ...                                   ...     ...            ...
# D7_D_TTTGTCAAGGTGTTAA                D7_D  1173.0       3.552554
# D7_D_TTTGTCACAGTCAGCC                D7_D  3268.0       1.923886
# D7_D_TTTGTCACATCGATGT                D7_D  2432.0       0.779578
# D7_D_TTTGTCAGTCCGTTAA                D7_D  1407.0       1.275917
# D7_D_TTTGTCAGTTTGTGTG                D7_D  3210.0       0.703876
#
#                          pct_counts_ribo    sample_id  doublet_scores  \
# TCGCAGGAGGCTTCCG-1-A9_2              NaN         A9_2        0.286585
# CCGTTCACAAATTGCC-1-A9_2              NaN         A9_2        0.130000
# CCAAGCGGTTTCGTAG-1-A9_2              NaN         A9_2        0.204651
# AACGGGACACTCAAGT-1-A9_2              NaN         A9_2        0.269565
# GGAATGGAGACAACAT-1-A9_2              NaN         A9_2        0.194631
# ...                                  ...          ...             ...
# D7_D_TTTGTCAAGGTGTTAA          12.536700  SRR10870305        0.063719
# D7_D_TTTGTCACAGTCAGCC          12.352817  SRR10870305        0.053763
# D7_D_TTTGTCACATCGATGT           9.859370  SRR10870305        0.034757
# D7_D_TTTGTCAGTCCGTTAA           7.934609  SRR10870305        0.006983
# D7_D_TTTGTCAGTTTGTGTG          11.668484  SRR10870305        0.027473
#
#                          n_genes_by_counts  total_counts  total_counts_mt  \
# TCGCAGGAGGCTTCCG-1-A9_2             4100.0        9536.0            493.0
# CCGTTCACAAATTGCC-1-A9_2             3727.0        8218.0            147.0
# CCAAGCGGTTTCGTAG-1-A9_2             3080.0        7227.0            365.0
# AACGGGACACTCAAGT-1-A9_2             3271.0        6503.0            165.0
# GGAATGGAGACAACAT-1-A9_2             2987.0        6277.0            375.0
# ...                                    ...           ...              ...
# D7_D_TTTGTCAAGGTGTTAA               1166.0        3406.0            121.0
# D7_D_TTTGTCACAGTCAGCC               3370.0        9512.0            183.0
# D7_D_TTTGTCACATCGATGT               2456.0        6542.0             51.0
# D7_D_TTTGTCAGTCCGTTAA               1420.0        2508.0             32.0
# D7_D_TTTGTCAGTTTGTGTG               3287.0       10087.0             71.0
#
#                          total_counts_ribo  percent_chrY  XIST-counts  \
# TCGCAGGAGGCTTCCG-1-A9_2              208.0      0.052433          0.0
# CCGTTCACAAATTGCC-1-A9_2               42.0      0.158189          0.0
# CCAAGCGGTTTCGTAG-1-A9_2              288.0      0.083022          0.0
# AACGGGACACTCAAGT-1-A9_2              113.0      0.107643          0.0
# GGAATGGAGACAACAT-1-A9_2              135.0      0.111518          0.0
# ...                                    ...           ...          ...
# D7_D_TTTGTCAAGGTGTTAA                427.0      0.000000          2.0
# D7_D_TTTGTCACAGTCAGCC               1175.0      0.021026         37.0
# D7_D_TTTGTCACATCGATGT                645.0      0.015286          4.0
# D7_D_TTTGTCAGTCCGTTAA                199.0      0.000000          0.0
# D7_D_TTTGTCAGTTTGTGTG               1177.0      0.000000         12.0
#
#                           S_score  G2M_score                cell_annotation  \
# TCGCAGGAGGCTTCCG-1-A9_2  0.138445  -0.249553                            FB6
# CCGTTCACAAATTGCC-1-A9_2  2.531231   4.013015                            FB4
# CCAAGCGGTTTCGTAG-1-A9_2 -0.197844  -0.295802                            FB6
# AACGGGACACTCAAGT-1-A9_2  0.319994   0.019119                            FB6
# GGAATGGAGACAACAT-1-A9_2  0.042216  -0.392916                            FB6
# ...                           ...        ...                            ...
# D7_D_TTTGTCAAGGTGTTAA   -0.210280  -0.512819  Anti-inflammatory macrophages
# D7_D_TTTGTCACAGTCAGCC   -0.064807   3.910752          MuSCs and progenitors
# D7_D_TTTGTCACATCGATGT   -0.206855  -0.657905                           FAPs
# D7_D_TTTGTCAGTCCGTTAA   -0.480220  -0.241352                    Endothelial
# D7_D_TTTGTCAGTTTGTGTG   -0.534799  -1.216019                           FAPs
#
#                         gender_check_cov
# TCGCAGGAGGCTTCCG-1-A9_2             Male
# CCGTTCACAAATTGCC-1-A9_2             Male
# CCAAGCGGTTTCGTAG-1-A9_2             Male
# AACGGGACACTCAAGT-1-A9_2             Male
# GGAATGGAGACAACAT-1-A9_2             Male
# ...                                  ...
# D7_D_TTTGTCAAGGTGTTAA             Female
# D7_D_TTTGTCACAGTCAGCC             Female
# D7_D_TTTGTCACATCGATGT             Female
# D7_D_TTTGTCAGTCCGTTAA               None
# D7_D_TTTGTCAGTTTGTGTG             Female
#
# [41891 rows x 16 columns]

# %%
integrated_fb.write(path +'fb_integrated_gse143437.h5ad')

# %% [markdown]
# # Lymphoid

# %% [markdown]
# ## Data loading

# %%
lym = ad.read_h5ad(path + 'heart_mm_nuclei-23-0092_scANVI-Lymphoid_states_ctl240527.raw.h5ad')
GSE143437 = ad.read_h5ad(path + 'GSE143437_QC_03_07_2024_raw.h5ad')

print("Columns in lym.obs:", lym.obs.columns)
print("Columns in GSE143437.obs:", GSE143437.obs.columns)
# Out:
# Columns in lym.obs: Index(['orig.ident', 'Age_group', 'BMI', 'COVID_severity', 'COVID_status',
#        'Ethnicity', 'Group', 'Sex', 'annotation_broad', 'annotation_detailed',
#        'sample_id', 'seed_labels', 'donor', 'cell_states', 'sample',
#        'cell_source', 'genotype', 'nCount_HTO', 'nFeature_HTO',
#        'HTO_classification', 'Library', 'CD45_Annotation', 'cell_type',
#        'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'region',
#        'scrublet_score', 'batch', 'doublet_scores', 'n_genes_by_counts',
#        'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo',
#        'pct_counts_ribo', 'percent_mt2', 'percent_chrY', 'XIST-counts',
#        'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'MPC_Annotation',
#        'compartment'],
#       dtype='object')
# Columns in GSE143437.obs: Index(['sample_id', 'sample_identifier', 'nUMI', 'nGene', 'percent_mito',
#        'injury', 'cell_annotation', 'doublet_scores', 'predicted_doublets',
#        'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt',
#        'total_counts_ribo', 'pct_counts_ribo', 'percent_chrY', 'XIST-counts',
#        'XIST-percentage', 'gender_check_cov', 'S_score', 'G2M_score', 'phase'],
#       dtype='object')

# %%
lym.obs['cell_type']
# Out:
# AAACGCTGTTATAGAG-1_1-MDX_POOL_NEW      CD8Tctl
# AAAGAACTCCCGTGTT-1_1-MDX_POOL_NEW            T
# AACAAAGAGCGTTGTT-1_1-MDX_POOL_NEW      CD8Tctl
# AACAAAGTCAAGCCTA-1_1-MDX_POOL_NEW    CD8Tnaive
# AACAAGAAGTTGAATG-1_1-MDX_POOL_NEW      CD8Tctl
#                                        ...
# TTCTAACAGTCACACT-1_2-MDX_MPC                NK
# TTGAGTGCACTCCGAG-1_2-MDX_MPC               gdT
# TTGGGCGTCCCGTGAG-1_2-MDX_MPC                NK
# TTTACTGAGATCACTC-1_2-MDX_MPC                NK
# TTTGGAGAGGATAATC-1_2-MDX_MPC                NK
# Name: cell_type, Length: 65544, dtype: category
# Categories (18, object): ['B_cells', 'B_mem', 'B_naive', 'CD4Tctl', ..., 'Plasma_cells', 'T', 'Treg', 'gdT']

# %% [markdown]
# ## Column renaming

# %% [markdown]
# ##### Steps
#
# 1. Mapping for columns that have the same information but different names
# 2. Rename columns in cmc to match those in GSE143437
# 3. Handle duplicate columns by making them unique
# 4. Find common columns and convert to list
# 5. Filter and rename columns in cmc and GSE143437 to match AnnData expectations
# 6. Concatenate the two datasets with inner join

# %%
lym.obs['gender_check_cov'] = 'Male' 

obs_rename_mapping = {
    'donor' : 'sample_identifier' ,
    'sample': 'sample_id',
    'n_genes': 'nGene',
    'percent_mito': 'pct_counts_mt',
    'percent_ribo': 'pct_counts_ribo',
    'pct_counts_mt' : 'pct_counts_mt', 
    'cell_type' : 'cell_annotation'
}


lym.obs.rename(columns=obs_rename_mapping, inplace=True)


def make_unique(column_names):
    seen = set()
    for idx, col in enumerate(column_names):
        while col in seen:
            col += '_dup'
        seen.add(col)
        column_names[idx] = col
    return column_names

lym.obs.columns = make_unique(list(lym.obs.columns))
GSE143437.obs.columns = make_unique(list(GSE143437.obs.columns))

lym.var.columns = make_unique(list(lym.var.columns))
GSE143437.var.columns = make_unique(list(GSE143437.var.columns))

common_obs_columns = list(set(lym.var.columns).intersection(set(GSE143437.var.columns)))
common_var_columns = list(set(lym.var.columns).intersection(set(GSE143437.var.columns)))

lym = lym[:, lym.var_names.isin(common_var_columns)].copy()
GSE143437 = GSE143437[:, GSE143437.var_names.isin(common_var_columns)].copy()

# %% [markdown]
# ## Integration

# %%
integrated_lym = ad.concat([lym, GSE143437], join='inner', index_unique=None)
integrated_lym.obs
# Out:
# /Users/srivalli/conda/envs/anndata/lib/python3.12/site-packages/anndata/_core/merge.py:1356: UserWarning: Only some AnnData objects have `.raw` attribute, not concatenating `.raw` attributes.
#   warn(
#                                      sample_id sample_identifier  \
# AAACGCTGTTATAGAG-1_1-MDX_POOL_NEW          NaN             Ctrl5
# AAAGAACTCCCGTGTT-1_1-MDX_POOL_NEW          NaN             Ctrl2
# AACAAAGAGCGTTGTT-1_1-MDX_POOL_NEW          NaN             Ctrl5
# AACAAAGTCAAGCCTA-1_1-MDX_POOL_NEW          NaN             Ctrl5
# AACAAGAAGTTGAATG-1_1-MDX_POOL_NEW          NaN             Ctrl4
# ...                                        ...               ...
# D7_D_TTTGTCAAGGTGTTAA              SRR10870305              D7_D
# D7_D_TTTGTCACAGTCAGCC              SRR10870305              D7_D
# D7_D_TTTGTCACATCGATGT              SRR10870305              D7_D
# D7_D_TTTGTCAGTCCGTTAA              SRR10870305              D7_D
# D7_D_TTTGTCAGTTTGTGTG              SRR10870305              D7_D
#
#                                                  cell_annotation   nGene  \
# AAACGCTGTTATAGAG-1_1-MDX_POOL_NEW                        CD8Tctl     NaN
# AAAGAACTCCCGTGTT-1_1-MDX_POOL_NEW                              T     NaN
# AACAAAGAGCGTTGTT-1_1-MDX_POOL_NEW                        CD8Tctl     NaN
# AACAAAGTCAAGCCTA-1_1-MDX_POOL_NEW                      CD8Tnaive     NaN
# AACAAGAAGTTGAATG-1_1-MDX_POOL_NEW                        CD8Tctl     NaN
# ...                                                          ...     ...
# D7_D_TTTGTCAAGGTGTTAA              Anti-inflammatory macrophages  1173.0
# D7_D_TTTGTCACAGTCAGCC                      MuSCs and progenitors  3268.0
# D7_D_TTTGTCACATCGATGT                                       FAPs  2432.0
# D7_D_TTTGTCAGTCCGTTAA                                Endothelial  1407.0
# D7_D_TTTGTCAGTTTGTGTG                                       FAPs  3210.0
#
#                                    pct_counts_mt  pct_counts_ribo  \
# AAACGCTGTTATAGAG-1_1-MDX_POOL_NEW            NaN              NaN
# AAAGAACTCCCGTGTT-1_1-MDX_POOL_NEW            NaN              NaN
# AACAAAGAGCGTTGTT-1_1-MDX_POOL_NEW            NaN              NaN
# AACAAAGTCAAGCCTA-1_1-MDX_POOL_NEW            NaN              NaN
# AACAAGAAGTTGAATG-1_1-MDX_POOL_NEW            NaN              NaN
# ...                                          ...              ...
# D7_D_TTTGTCAAGGTGTTAA                   3.552554        12.536700
# D7_D_TTTGTCACAGTCAGCC                   1.923886        12.352817
# D7_D_TTTGTCACATCGATGT                   0.779578         9.859370
# D7_D_TTTGTCAGTCCGTTAA                   1.275917         7.934609
# D7_D_TTTGTCAGTTTGTGTG                   0.703876        11.668484
#
#                                    doublet_scores  n_genes_by_counts  \
# AAACGCTGTTATAGAG-1_1-MDX_POOL_NEW             NaN                NaN
# AAAGAACTCCCGTGTT-1_1-MDX_POOL_NEW             NaN                NaN
# AACAAAGAGCGTTGTT-1_1-MDX_POOL_NEW             NaN                NaN
# AACAAAGTCAAGCCTA-1_1-MDX_POOL_NEW             NaN                NaN
# AACAAGAAGTTGAATG-1_1-MDX_POOL_NEW             NaN                NaN
# ...                                           ...                ...
# D7_D_TTTGTCAAGGTGTTAA                    0.063719             1166.0
# D7_D_TTTGTCACAGTCAGCC                    0.053763             3370.0
# D7_D_TTTGTCACATCGATGT                    0.034757             2456.0
# D7_D_TTTGTCAGTCCGTTAA                    0.006983             1420.0
# D7_D_TTTGTCAGTTTGTGTG                    0.027473             3287.0
#
#                                    total_counts  total_counts_mt  \
# AAACGCTGTTATAGAG-1_1-MDX_POOL_NEW           NaN              NaN
# AAAGAACTCCCGTGTT-1_1-MDX_POOL_NEW           NaN              NaN
# AACAAAGAGCGTTGTT-1_1-MDX_POOL_NEW           NaN              NaN
# AACAAAGTCAAGCCTA-1_1-MDX_POOL_NEW           NaN              NaN
# AACAAGAAGTTGAATG-1_1-MDX_POOL_NEW           NaN              NaN
# ...                                         ...              ...
# D7_D_TTTGTCAAGGTGTTAA                    3406.0            121.0
# D7_D_TTTGTCACAGTCAGCC                    9512.0            183.0
# D7_D_TTTGTCACATCGATGT                    6542.0             51.0
# D7_D_TTTGTCAGTCCGTTAA                    2508.0             32.0
# D7_D_TTTGTCAGTTTGTGTG                   10087.0             71.0
#
#                                    total_counts_ribo  percent_chrY  \
# AAACGCTGTTATAGAG-1_1-MDX_POOL_NEW                NaN           NaN
# AAAGAACTCCCGTGTT-1_1-MDX_POOL_NEW                NaN           NaN
# AACAAAGAGCGTTGTT-1_1-MDX_POOL_NEW                NaN           NaN
# AACAAAGTCAAGCCTA-1_1-MDX_POOL_NEW                NaN           NaN
# AACAAGAAGTTGAATG-1_1-MDX_POOL_NEW                NaN           NaN
# ...                                              ...           ...
# D7_D_TTTGTCAAGGTGTTAA                          427.0      0.000000
# D7_D_TTTGTCACAGTCAGCC                         1175.0      0.021026
# D7_D_TTTGTCACATCGATGT                          645.0      0.015286
# D7_D_TTTGTCAGTCCGTTAA                          199.0      0.000000
# D7_D_TTTGTCAGTTTGTGTG                         1177.0      0.000000
#
#                                    XIST-counts   S_score  G2M_score  \
# AAACGCTGTTATAGAG-1_1-MDX_POOL_NEW          NaN       NaN        NaN
# AAAGAACTCCCGTGTT-1_1-MDX_POOL_NEW          NaN       NaN        NaN
# AACAAAGAGCGTTGTT-1_1-MDX_POOL_NEW          NaN       NaN        NaN
# AACAAAGTCAAGCCTA-1_1-MDX_POOL_NEW          NaN       NaN        NaN
# AACAAGAAGTTGAATG-1_1-MDX_POOL_NEW          NaN       NaN        NaN
# ...                                        ...       ...        ...
# D7_D_TTTGTCAAGGTGTTAA                      2.0 -0.210280  -0.512819
# D7_D_TTTGTCACAGTCAGCC                     37.0 -0.064807   3.910752
# D7_D_TTTGTCACATCGATGT                      4.0 -0.206855  -0.657905
# D7_D_TTTGTCAGTCCGTTAA                      0.0 -0.480220  -0.241352
# D7_D_TTTGTCAGTTTGTGTG                     12.0 -0.534799  -1.216019
#
#                                   gender_check_cov
# AAACGCTGTTATAGAG-1_1-MDX_POOL_NEW             Male
# AAAGAACTCCCGTGTT-1_1-MDX_POOL_NEW             Male
# AACAAAGAGCGTTGTT-1_1-MDX_POOL_NEW             Male
# AACAAAGTCAAGCCTA-1_1-MDX_POOL_NEW             Male
# AACAAGAAGTTGAATG-1_1-MDX_POOL_NEW             Male
# ...                                            ...
# D7_D_TTTGTCAAGGTGTTAA                       Female
# D7_D_TTTGTCACAGTCAGCC                       Female
# D7_D_TTTGTCACATCGATGT                       Female
# D7_D_TTTGTCAGTCCGTTAA                         None
# D7_D_TTTGTCAGTTTGTGTG                       Female
#
# [98058 rows x 16 columns]

# %%
integrated_lym.write(path + 'lym_integrated_gse143437.h5ad')

# %% [markdown]
# # Myeloid

# %% [markdown]
# ## Data loading

# %%
mye = ad.read_h5ad(path + 'heart_mm_nuclei-23-0092_scANVI-Myeloid_states_ctl240502.raw.h5ad')
GSE143437 = ad.read_h5ad(path + 'GSE143437_QC_03_07_2024_raw.h5ad')

print("Columns in mye.obs:", mye.obs.columns)
print("Columns in GSE143437.obs:", GSE143437.obs.columns)
# Out:
# Columns in mye.obs: Index(['orig.ident', 'Age_group', 'BMI', 'COVID_severity', 'COVID_status',
#        'Ethnicity', 'Group', 'Sex', 'annotation_broad', 'annotation_detailed',
#        'sample_id', 'seed_labels', 'donor', 'cell_states', 'sample',
#        'cell_source', 'genotype', 'nCount_HTO', 'nFeature_HTO',
#        'HTO_classification', 'Library', 'CD45_Annotation', 'cell_type',
#        'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'region',
#        'scrublet_score', 'batch', 'doublet_scores', 'n_genes_by_counts',
#        'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo',
#        'pct_counts_ribo', 'percent_mt2', 'percent_chrY', 'XIST-counts',
#        'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'MPC_Annotation',
#        'compartment'],
#       dtype='object')
# Columns in GSE143437.obs: Index(['sample_id', 'sample_identifier', 'nUMI', 'nGene', 'percent_mito',
#        'injury', 'cell_annotation', 'doublet_scores', 'predicted_doublets',
#        'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt',
#        'total_counts_ribo', 'pct_counts_ribo', 'percent_chrY', 'XIST-counts',
#        'XIST-percentage', 'gender_check_cov', 'S_score', 'G2M_score', 'phase'],
#       dtype='object')

# %%
mye.obs['cell_type']
# Out:
# AAACCCAGTCAAGCGA-1_1-MDX_POOL_NEW           TLF+MØ
# AAACCCAGTGGCTTGC-1_1-MDX_POOL_NEW           TLF+MØ
# AAACGCTGTAGTTACC-1_1-MDX_POOL_NEW           TLF+MØ
# AAAGGATGTTATCTGG-1_1-MDX_POOL_NEW         Ly6CloMo
# AAAGGATTCGTAGTCA-1_1-MDX_POOL_NEW              DC2
#                                          ...
# TTTGGAGAGCGACTGA-1_2-MDX_MPC-1          MHCII+MØtr
# TTTGGAGAGGATAATC-1_2-MDX_MPC-1              TLF+MØ
# TTTGGAGTCTCGGCTT-1_2-MDX_MPC-1          MHCII+MØtr
# TTTGTTGAGATTCGAA-1_2-MDX_MPC-1          MHCII+MØtr
# TTTGTTGGTGATATAG-1_2-MDX_MPC-1       Ccr2+MHCII+MØ
# Name: cell_type, Length: 41716, dtype: category
# Categories (12, object): ['Ccr2+MHCII+MØ', 'DC', 'DC2', 'Isg15+MØ', ..., 'MØinf', 'NØ', 'Spp1+Gpnmb+MØ', 'TLF+MØ']

# %% [markdown]
# ## Column renaming

# %% [markdown]
# ##### Steps
#
# 1. Mapping for columns that have the same information but different names
# 2. Rename columns in cmc to match those in GSE143437
# 3. Handle duplicate columns by making them unique
# 4. Find common columns and convert to list
# 5. Filter and rename columns in cmc and GSE143437 to match AnnData expectations
# 6. Concatenate the two datasets with inner join

# %%
mye.obs['gender_check_cov'] = 'Male' 

obs_rename_mapping = {
    'donor' : 'sample_identifier' ,
    'sample': 'sample_id',
    'n_genes': 'nGene',
    'percent_mito': 'pct_counts_mt',
    'percent_ribo': 'pct_counts_ribo',
    'pct_counts_mt' : 'pct_counts_mt', 
    'cell_type' : 'cell_annotation'
}


mye.obs.rename(columns=obs_rename_mapping, inplace=True)


def make_unique(column_names):
    seen = set()
    for idx, col in enumerate(column_names):
        while col in seen:
            col += '_dup'
        seen.add(col)
        column_names[idx] = col
    return column_names

mye.obs.columns = make_unique(list(mye.obs.columns))
GSE143437.obs.columns = make_unique(list(GSE143437.obs.columns))

mye.var.columns = make_unique(list(mye.var.columns))
GSE143437.var.columns = make_unique(list(GSE143437.var.columns))

common_obs_columns = list(set(mye.var.columns).intersection(set(GSE143437.var.columns)))
common_var_columns = list(set(mye.var.columns).intersection(set(GSE143437.var.columns)))

mye = mye[:, mye.var_names.isin(common_var_columns)].copy()
GSE143437 = GSE143437[:, GSE143437.var_names.isin(common_var_columns)].copy()

# %% [markdown]
# ## Integration

# %%
integrated_mye= ad.concat([mye, GSE143437], join='inner', index_unique=None)
integrated_mye.obs
# Out:
# /Users/srivalli/conda/envs/anndata/lib/python3.12/site-packages/anndata/_core/merge.py:1356: UserWarning: Only some AnnData objects have `.raw` attribute, not concatenating `.raw` attributes.
#   warn(
#                                      sample_id sample_identifier  \
# AAACCCAGTCAAGCGA-1_1-MDX_POOL_NEW          NaN             Ctrl2
# AAACCCAGTGGCTTGC-1_1-MDX_POOL_NEW          NaN             Ctrl3
# AAACGCTGTAGTTACC-1_1-MDX_POOL_NEW          NaN             Ctrl4
# AAAGGATGTTATCTGG-1_1-MDX_POOL_NEW          NaN             Ctrl1
# AAAGGATTCGTAGTCA-1_1-MDX_POOL_NEW          NaN             Ctrl5
# ...                                        ...               ...
# D7_D_TTTGTCAAGGTGTTAA              SRR10870305              D7_D
# D7_D_TTTGTCACAGTCAGCC              SRR10870305              D7_D
# D7_D_TTTGTCACATCGATGT              SRR10870305              D7_D
# D7_D_TTTGTCAGTCCGTTAA              SRR10870305              D7_D
# D7_D_TTTGTCAGTTTGTGTG              SRR10870305              D7_D
#
#                                                  cell_annotation   nGene  \
# AAACCCAGTCAAGCGA-1_1-MDX_POOL_NEW                         TLF+MØ     NaN
# AAACCCAGTGGCTTGC-1_1-MDX_POOL_NEW                         TLF+MØ     NaN
# AAACGCTGTAGTTACC-1_1-MDX_POOL_NEW                         TLF+MØ     NaN
# AAAGGATGTTATCTGG-1_1-MDX_POOL_NEW                       Ly6CloMo     NaN
# AAAGGATTCGTAGTCA-1_1-MDX_POOL_NEW                            DC2     NaN
# ...                                                          ...     ...
# D7_D_TTTGTCAAGGTGTTAA              Anti-inflammatory macrophages  1173.0
# D7_D_TTTGTCACAGTCAGCC                      MuSCs and progenitors  3268.0
# D7_D_TTTGTCACATCGATGT                                       FAPs  2432.0
# D7_D_TTTGTCAGTCCGTTAA                                Endothelial  1407.0
# D7_D_TTTGTCAGTTTGTGTG                                       FAPs  3210.0
#
#                                    pct_counts_mt  pct_counts_ribo  \
# AAACCCAGTCAAGCGA-1_1-MDX_POOL_NEW            NaN              NaN
# AAACCCAGTGGCTTGC-1_1-MDX_POOL_NEW            NaN              NaN
# AAACGCTGTAGTTACC-1_1-MDX_POOL_NEW            NaN              NaN
# AAAGGATGTTATCTGG-1_1-MDX_POOL_NEW            NaN              NaN
# AAAGGATTCGTAGTCA-1_1-MDX_POOL_NEW            NaN              NaN
# ...                                          ...              ...
# D7_D_TTTGTCAAGGTGTTAA                   3.552554        12.536700
# D7_D_TTTGTCACAGTCAGCC                   1.923886        12.352817
# D7_D_TTTGTCACATCGATGT                   0.779578         9.859370
# D7_D_TTTGTCAGTCCGTTAA                   1.275917         7.934609
# D7_D_TTTGTCAGTTTGTGTG                   0.703876        11.668484
#
#                                    doublet_scores  n_genes_by_counts  \
# AAACCCAGTCAAGCGA-1_1-MDX_POOL_NEW             NaN                NaN
# AAACCCAGTGGCTTGC-1_1-MDX_POOL_NEW             NaN                NaN
# AAACGCTGTAGTTACC-1_1-MDX_POOL_NEW             NaN                NaN
# AAAGGATGTTATCTGG-1_1-MDX_POOL_NEW             NaN                NaN
# AAAGGATTCGTAGTCA-1_1-MDX_POOL_NEW             NaN                NaN
# ...                                           ...                ...
# D7_D_TTTGTCAAGGTGTTAA                    0.063719             1166.0
# D7_D_TTTGTCACAGTCAGCC                    0.053763             3370.0
# D7_D_TTTGTCACATCGATGT                    0.034757             2456.0
# D7_D_TTTGTCAGTCCGTTAA                    0.006983             1420.0
# D7_D_TTTGTCAGTTTGTGTG                    0.027473             3287.0
#
#                                    total_counts  total_counts_mt  \
# AAACCCAGTCAAGCGA-1_1-MDX_POOL_NEW           NaN              NaN
# AAACCCAGTGGCTTGC-1_1-MDX_POOL_NEW           NaN              NaN
# AAACGCTGTAGTTACC-1_1-MDX_POOL_NEW           NaN              NaN
# AAAGGATGTTATCTGG-1_1-MDX_POOL_NEW           NaN              NaN
# AAAGGATTCGTAGTCA-1_1-MDX_POOL_NEW           NaN              NaN
# ...                                         ...              ...
# D7_D_TTTGTCAAGGTGTTAA                    3406.0            121.0
# D7_D_TTTGTCACAGTCAGCC                    9512.0            183.0
# D7_D_TTTGTCACATCGATGT                    6542.0             51.0
# D7_D_TTTGTCAGTCCGTTAA                    2508.0             32.0
# D7_D_TTTGTCAGTTTGTGTG                   10087.0             71.0
#
#                                    total_counts_ribo  percent_chrY  \
# AAACCCAGTCAAGCGA-1_1-MDX_POOL_NEW                NaN           NaN
# AAACCCAGTGGCTTGC-1_1-MDX_POOL_NEW                NaN           NaN
# AAACGCTGTAGTTACC-1_1-MDX_POOL_NEW                NaN           NaN
# AAAGGATGTTATCTGG-1_1-MDX_POOL_NEW                NaN           NaN
# AAAGGATTCGTAGTCA-1_1-MDX_POOL_NEW                NaN           NaN
# ...                                              ...           ...
# D7_D_TTTGTCAAGGTGTTAA                          427.0      0.000000
# D7_D_TTTGTCACAGTCAGCC                         1175.0      0.021026
# D7_D_TTTGTCACATCGATGT                          645.0      0.015286
# D7_D_TTTGTCAGTCCGTTAA                          199.0      0.000000
# D7_D_TTTGTCAGTTTGTGTG                         1177.0      0.000000
#
#                                    XIST-counts   S_score  G2M_score  \
# AAACCCAGTCAAGCGA-1_1-MDX_POOL_NEW          NaN       NaN        NaN
# AAACCCAGTGGCTTGC-1_1-MDX_POOL_NEW          NaN       NaN        NaN
# AAACGCTGTAGTTACC-1_1-MDX_POOL_NEW          NaN       NaN        NaN
# AAAGGATGTTATCTGG-1_1-MDX_POOL_NEW          NaN       NaN        NaN
# AAAGGATTCGTAGTCA-1_1-MDX_POOL_NEW          NaN       NaN        NaN
# ...                                        ...       ...        ...
# D7_D_TTTGTCAAGGTGTTAA                      2.0 -0.210280  -0.512819
# D7_D_TTTGTCACAGTCAGCC                     37.0 -0.064807   3.910752
# D7_D_TTTGTCACATCGATGT                      4.0 -0.206855  -0.657905
# D7_D_TTTGTCAGTCCGTTAA                      0.0 -0.480220  -0.241352
# D7_D_TTTGTCAGTTTGTGTG                     12.0 -0.534799  -1.216019
#
#                                   gender_check_cov
# AAACCCAGTCAAGCGA-1_1-MDX_POOL_NEW             Male
# AAACCCAGTGGCTTGC-1_1-MDX_POOL_NEW             Male
# AAACGCTGTAGTTACC-1_1-MDX_POOL_NEW             Male
# AAAGGATGTTATCTGG-1_1-MDX_POOL_NEW             Male
# AAAGGATTCGTAGTCA-1_1-MDX_POOL_NEW             Male
# ...                                            ...
# D7_D_TTTGTCAAGGTGTTAA                       Female
# D7_D_TTTGTCACAGTCAGCC                       Female
# D7_D_TTTGTCACATCGATGT                       Female
# D7_D_TTTGTCAGTCCGTTAA                         None
# D7_D_TTTGTCAGTTTGTGTG                       Female
#
# [74230 rows x 16 columns]

# %%
integrated_mye.write(path + 'mye_integrated_gse143437.h5ad')

# %% [markdown]
# # Vascular

# %% [markdown]
# ## Data loading

# %%
vas = ad.read_h5ad(path + 'heart_mm_nuclei-23-0092_scANVI-vascular_states_ctl240131.raw.h5ad')
GSE143437 = ad.read_h5ad(path + 'GSE143437_QC_03_07_2024_raw.h5ad')

print("Columns in vas.obs:", vas.obs.columns)
print("Columns in GSE143437.obs:", GSE143437.obs.columns)
# Out:
# Columns in vas.obs: Index(['cell_source', 'cell_type', 'donor', 'n_counts', 'n_genes',
#        'percent_mito', 'percent_ribo', 'region', 'sample', 'scrublet_score',
#        'cell_states', 'seed_labels', 'genotype', 'batch', 'doublet_scores',
#        'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt',
#        'total_counts_ribo', 'pct_counts_ribo', 'percent_mt2', 'percent_chrY',
#        'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels',
#        'C_scANVI'],
#       dtype='object')
# Columns in GSE143437.obs: Index(['sample_id', 'sample_identifier', 'nUMI', 'nGene', 'percent_mito',
#        'injury', 'cell_annotation', 'doublet_scores', 'predicted_doublets',
#        'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt',
#        'total_counts_ribo', 'pct_counts_ribo', 'percent_chrY', 'XIST-counts',
#        'XIST-percentage', 'gender_check_cov', 'S_score', 'G2M_score', 'phase'],
#       dtype='object')

# %% [markdown]
# ## Column renaming

# %% [markdown]
# ##### Steps
#
# 1. Mapping for columns that have the same information but different names
# 2. Rename columns in cmc to match those in GSE143437
# 3. Handle duplicate columns by making them unique
# 4. Find common columns and convert to list
# 5. Filter and rename columns in cmc and GSE143437 to match AnnData expectations
# 6. Concatenate the two datasets with inner join

# %%
vas.obs['gender_check_cov'] = 'Male' 

del vas.obs['cell_type']


obs_rename_mapping = {
    'donor' : 'sample_identifier' ,
    'sample': 'sample_id',
    'n_genes': 'nGene',
    'percent_mito': 'pct_counts_mt',
    'percent_ribo': 'pct_counts_ribo',
    'pct_counts_mt' : 'pct_counts_mt', 
    'C_scANVI' : 'cell_annotation'
}


vas.obs.rename(columns=obs_rename_mapping, inplace=True)


def make_unique(column_names):
    seen = set()
    for idx, col in enumerate(column_names):
        while col in seen:
            col += '_dup'
        seen.add(col)
        column_names[idx] = col
    return column_names

vas.obs.columns = make_unique(list(vas.obs.columns))
GSE143437.obs.columns = make_unique(list(GSE143437.obs.columns))

vas.var.columns = make_unique(list(vas.var.columns))
GSE143437.var.columns = make_unique(list(GSE143437.var.columns))

common_obs_columns = list(set(vas.var.columns).intersection(set(GSE143437.var.columns)))
common_var_columns = list(set(vas.var.columns).intersection(set(GSE143437.var.columns)))

vas = vas[:, vas.var_names.isin(common_var_columns)].copy()
GSE143437 = GSE143437[:, GSE143437.var_names.isin(common_var_columns)].copy()

# %% [markdown]
# ## Integration

# %%
integrated_vas= ad.concat([vas, GSE143437], join='inner', index_unique=None)
integrated_vas.obs
# Out:
# /Users/srivalli/conda/envs/anndata/lib/python3.12/site-packages/anndata/_core/merge.py:1356: UserWarning: Only some AnnData objects have `.raw` attribute, not concatenating `.raw` attributes.
#   warn(
#                         sample_identifier   nGene  pct_counts_mt  \
# CTCCAACCACAAGTTC-1-A9_2              A9_2  4489.0            NaN
# AGGTTGTCAGCACGAA-1-A9_2              A9_2  4408.0            NaN
# AGGCCACCAGAAGCTG-1-A9_2              A9_2  4665.0            NaN
# AGTCTCCCACGATAGG-1-A9_2              A9_2  4438.0            NaN
# GGACGTCCAATCCAGT-1-A9_2              A9_2  4604.0            NaN
# ...                                   ...     ...            ...
# D7_D_TTTGTCAAGGTGTTAA                D7_D  1173.0       3.552554
# D7_D_TTTGTCACAGTCAGCC                D7_D  3268.0       1.923886
# D7_D_TTTGTCACATCGATGT                D7_D  2432.0       0.779578
# D7_D_TTTGTCAGTCCGTTAA                D7_D  1407.0       1.275917
# D7_D_TTTGTCAGTTTGTGTG                D7_D  3210.0       0.703876
#
#                          pct_counts_ribo    sample_id  doublet_scores  \
# CTCCAACCACAAGTTC-1-A9_2              NaN         A9_2        0.286585
# AGGTTGTCAGCACGAA-1-A9_2              NaN         A9_2        0.326531
# AGGCCACCAGAAGCTG-1-A9_2              NaN         A9_2        0.269565
# AGTCTCCCACGATAGG-1-A9_2              NaN         A9_2        0.305466
# GGACGTCCAATCCAGT-1-A9_2              NaN         A9_2        0.254144
# ...                                  ...          ...             ...
# D7_D_TTTGTCAAGGTGTTAA          12.536700  SRR10870305        0.063719
# D7_D_TTTGTCACAGTCAGCC          12.352817  SRR10870305        0.053763
# D7_D_TTTGTCACATCGATGT           9.859370  SRR10870305        0.034757
# D7_D_TTTGTCAGTCCGTTAA           7.934609  SRR10870305        0.006983
# D7_D_TTTGTCAGTTTGTGTG          11.668484  SRR10870305        0.027473
#
#                          n_genes_by_counts  total_counts  total_counts_mt  \
# CTCCAACCACAAGTTC-1-A9_2             4489.0       13466.0            220.0
# AGGTTGTCAGCACGAA-1-A9_2             4408.0       12946.0            274.0
# AGGCCACCAGAAGCTG-1-A9_2             4665.0       13071.0            754.0
# AGTCTCCCACGATAGG-1-A9_2             4438.0       12511.0            282.0
# GGACGTCCAATCCAGT-1-A9_2             4604.0       12519.0            984.0
# ...                                    ...           ...              ...
# D7_D_TTTGTCAAGGTGTTAA               1166.0        3406.0            121.0
# D7_D_TTTGTCACAGTCAGCC               3370.0        9512.0            183.0
# D7_D_TTTGTCACATCGATGT               2456.0        6542.0             51.0
# D7_D_TTTGTCAGTCCGTTAA               1420.0        2508.0             32.0
# D7_D_TTTGTCAGTTTGTGTG               3287.0       10087.0             71.0
#
#                          total_counts_ribo  percent_chrY  XIST-counts  \
# CTCCAACCACAAGTTC-1-A9_2              117.0      0.051983          0.0
# AGGTTGTCAGCACGAA-1-A9_2               59.0      0.046346          0.0
# AGGCCACCAGAAGCTG-1-A9_2              282.0      0.045903          3.0
# AGTCTCCCACGATAGG-1-A9_2               97.0      0.103909          0.0
# GGACGTCCAATCCAGT-1-A9_2              320.0      0.031951          0.0
# ...                                    ...           ...          ...
# D7_D_TTTGTCAAGGTGTTAA                427.0      0.000000          2.0
# D7_D_TTTGTCACAGTCAGCC               1175.0      0.021026         37.0
# D7_D_TTTGTCACATCGATGT                645.0      0.015286          4.0
# D7_D_TTTGTCAGTCCGTTAA                199.0      0.000000          0.0
# D7_D_TTTGTCAGTTTGTGTG               1177.0      0.000000         12.0
#
#                           S_score  G2M_score                cell_annotation  \
# CTCCAACCACAAGTTC-1-A9_2 -0.355854  -0.387663                       SMC2_art
# AGGTTGTCAGCACGAA-1-A9_2 -0.264880  -0.409038                       SMC2_art
# AGGCCACCAGAAGCTG-1-A9_2  0.299016  -0.284226                       SMC2_art
# AGTCTCCCACGATAGG-1-A9_2 -0.133833  -0.517638                       SMC2_art
# GGACGTCCAATCCAGT-1-A9_2 -0.502134  -0.341586                      EC7_atria
# ...                           ...        ...                            ...
# D7_D_TTTGTCAAGGTGTTAA   -0.210280  -0.512819  Anti-inflammatory macrophages
# D7_D_TTTGTCACAGTCAGCC   -0.064807   3.910752          MuSCs and progenitors
# D7_D_TTTGTCACATCGATGT   -0.206855  -0.657905                           FAPs
# D7_D_TTTGTCAGTCCGTTAA   -0.480220  -0.241352                    Endothelial
# D7_D_TTTGTCAGTTTGTGTG   -0.534799  -1.216019                           FAPs
#
#                         gender_check_cov
# CTCCAACCACAAGTTC-1-A9_2             Male
# AGGTTGTCAGCACGAA-1-A9_2             Male
# AGGCCACCAGAAGCTG-1-A9_2             Male
# AGTCTCCCACGATAGG-1-A9_2             Male
# GGACGTCCAATCCAGT-1-A9_2             Male
# ...                                  ...
# D7_D_TTTGTCAAGGTGTTAA             Female
# D7_D_TTTGTCACAGTCAGCC             Female
# D7_D_TTTGTCACATCGATGT             Female
# D7_D_TTTGTCAGTCCGTTAA               None
# D7_D_TTTGTCAGTTTGTGTG             Female
#
# [54965 rows x 16 columns]

# %%
integrated_vas.write(path + 'vas_integrated_gse143437.h5ad')
